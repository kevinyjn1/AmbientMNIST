# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data as a string (copy the full data you provided)
data_str = "F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(13.0),F_LIT(30.0),F_LIT(32.0),F_LIT(31.0),F_LIT(20.0),F_LIT(17.0),F_LIT(17.0),F_LIT(7.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(24.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(29.0),F_LIT(16.0),F_LIT(4.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(5.0),F_LIT(13.0),F_LIT(19.0),F_LIT(10.0),F_LIT(10.0),F_LIT(13.0),F_LIT(21.0),F_LIT(21.0),F_LIT(29.0),F_LIT(28.0),F_LIT(9.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(7.0),F_LIT(30.0),F_LIT(29.0),F_LIT(4.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(15.0),F_LIT(31.0),F_LIT(24.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(1.0),F_LIT(18.0),F_LIT(30.0),F_LIT(31.0),F_LIT(24.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(4.0),F_LIT(7.0),F_LIT(26.0),F_LIT(31.0),F_LIT(31.0),F_LIT(28.0),F_LIT(5.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(1.0),F_LIT(14.0),F_LIT(25.0),F_LIT(29.0),F_LIT(30.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(15.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(13.0),F_LIT(23.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(30.0),F_LIT(30.0),F_LIT(31.0),F_LIT(22.0),F_LIT(2.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(24.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(25.0),F_LIT(10.0),F_LIT(8.0),F_LIT(8.0),F_LIT(16.0),F_LIT(28.0),F_LIT(29.0),F_LIT(10.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(19.0),F_LIT(31.0),F_LIT(21.0),F_LIT(21.0),F_LIT(10.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(5.0),F_LIT(21.0),F_LIT(29.0),F_LIT(14.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(1.0),F_LIT(3.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(13.0),F_LIT(28.0),F_LIT(18.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(14.0),F_LIT(30.0),F_LIT(7.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(17.0),F_LIT(31.0),F_LIT(24.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(13.0),F_LIT(30.0),F_LIT(31.0),F_LIT(24.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(1.0),F_LIT(17.0),F_LIT(30.0),F_LIT(31.0),F_LIT(30.0),F_LIT(7.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(2.0),F_LIT(2.0),F_LIT(3.0),F_LIT(3.0),F_LIT(14.0),F_LIT(17.0),F_LIT(25.0),F_LIT(31.0),F_LIT(31.0),F_LIT(30.0),F_LIT(18.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(7.0),F_LIT(29.0),F_LIT(26.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(26.0),F_LIT(13.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(10.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(31.0),F_LIT(30.0),F_LIT(11.0),F_LIT(1.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(4.0),F_LIT(28.0),F_LIT(31.0),F_LIT(30.0),F_LIT(17.0),F_LIT(17.0),F_LIT(17.0),F_LIT(3.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0),F_LIT(0.0)"

# Clean up the data string
data_str = data_str.replace('F_LIT(', '').replace(')', '').replace(';', '').replace('}', '').replace('{', '').strip()

# Split the data into a list
data_list = data_str.split(',')

# Convert the strings to floats
data = [float(value) for value in data_list if value.strip() != '']

# Ensure we have 784 values (28x28)
assert len(data) == 28*28, f"Expected 784 values, got {len(data)}"

# Convert to a NumPy array and reshape to 28x28
image_array = np.array(data).reshape(28, 28)

# Display the image
plt.imshow(image_array, cmap='gray')
plt.title('28x28 Grayscale Image')
plt.axis('off')
plt.show()
