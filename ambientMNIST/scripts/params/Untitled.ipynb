# %%
import pickle

# %%
# 가중치와 편향 불러오기 예시
with open('./conv1_w_.param', 'rb') as f_w:
    conv1_weights = pickle.load(f_w)
    print(conv1_weights.shape)
    print(conv1_weights)
# Out:
# (3, 3, 1, 16)
# [[[[-0.11552551  0.13407518 -0.03422834  0.11445998 -0.11945705
#      0.09329553  0.04422517  0.08082347  0.01539154 -0.12507848
#      0.17176218  0.1286134  -0.00162023  0.06850733 -0.15728664
#      0.04130353]]
#
#   [[ 0.09402873  0.07440044  0.06823827 -0.056527   -0.11216407
#      0.1870806   0.11267568  0.03839482 -0.18837327  0.01060529
#     -0.13017735 -0.01768222  0.02046756  0.08925606  0.01935978
#      0.05920516]]
#
#   [[-0.12391995 -0.06993632 -0.12448694  0.10330816 -0.18850188
#     -0.05597351  0.03684479  0.16620089  0.16803913 -0.13198598
#     -0.19644572 -0.16323847  0.14540441 -0.0490223  -0.08472107
#     -0.05461739]]]
#
#
#  [[[ 0.06974538  0.16555668  0.12152393  0.0468608   0.03508702
#     -0.01176122  0.02594391  0.00615509 -0.13127139 -0.09862457
#     -0.1977652  -0.04471771  0.16126059  0.13485275  0.03123744
#      0.04419208]]
#
#   [[-0.17294016  0.11454092 -0.09611294 -0.14579996 -0.01708785
# ...
